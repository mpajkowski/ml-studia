# %%
raw_data = open("dane.txt").read().strip().split("\n")

# %%
c1 = []
c2 = []

for line in raw_data:
    valX, valC = line.split()
    valX = float(valX)
    valC = int(float(valC))
    
    T = c2 if valC != 1 else c1
    T.append(valX)

# %%
# %matplotlib notebook

import matplotlib.pylab as plt
plt.hist((c1, c2), 40)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([array([ 2.,  0.,  0.,  0.,  1.,  2.,  3.,  4.,  1.,  6.,  5.,  3.,  9.,
#           9.,  3.,  7., 13., 10., 11., 11., 16., 13.,  7., 11.,  7., 12.,
#           7., 10.,  1.,  2.,  2.,  2.,  5.,  2.,  1.,  2.,  0.,  0.,  0.,
#           1.]),
#   array([ 0.,  0.,  0.,  1.,  1.,  3.,  1.,  6.,  9., 10., 16., 21., 24.,
#          33., 35., 48., 38., 47., 41., 36., 49., 42., 29., 30., 22., 13.,
#          17.,  5.,  2.,  9.,  2.,  0.,  0.,  1.,  0.,  0.,  0.,  0.,  0.,
#           0.])],
#  array([-0.393452  , -0.23738413, -0.08131625,  0.07475162,  0.2308195 ,
#          0.38688737,  0.54295525,  0.69902312,  0.855091  ,  1.01115888,
#          1.16722675,  1.32329462,  1.4793625 ,  1.63543037,  1.79149825,
#          1.94756612,  2.103634  ,  2.25970188,  2.41576975,  2.57183763,
#          2.7279055 ,  2.88397338,  3.04004125,  3.19610912,  3.352177  ,
#          3.50824487,  3.66431275,  3.82038063,  3.9764485 ,  4.13251637,
#          4.28858425,  4.44465213,  4.60072   ,  4.75678787,  4.91285575,
#          5.06892363,  5.2249915 ,  5.38105937,  5.53712725,  5.69319512,
#          5.849263  ]),
#  <a list of 2 Lists of Patches objects>)

# %%
# helper functions
import math

def mean(array):
    res = sum(array) / len(array)
    return round(res, 3)
  
def standard_deviation(array):
    m = round(mean(array), 3)
    return round(math.sqrt(sum((i - m) ** 2 for i in array) / (len(array) - 1)), 3)

def computeZ(arr1, arr2):
    mean_1 = mean(arr1)
    mean_2 = mean(arr2)
    stdev_1 = standard_deviation(arr1)
    stdev_2 = standard_deviation(arr2)
    z = (mean_1 - mean_2) \
      / math.sqrt(stdev_1 / len(arr1) + stdev_2 / len(arr2))
    
    return round(z, 3)

def computeDF(arr1, arr2):
    s1 = standard_deviation(arr1)
    s2 = standard_deviation(arr2)
    
    s1_squared = (s1 ** 2)
    s2_squared = (s2 ** 2)
    n1 = len(arr1)
    n2 = len(arr2)

    DF = (s1_squared / n1 + s2_squared / n2) ** 2 \
       / (( (s1_squared / n1) ** 2 / (n1 - 1)) \
       + (  (s2_squared / n2) ** 2 / (n2 - 1)))

    return round(DF, 3)

# %%
mean_c1, stdev_c1 = mean(c1), standard_deviation(c1)
mean_c2, stdev_c2 = mean(c2), standard_deviation(c2)

z = computeZ(c1,c2)
df = computeDF(c1, c2)

# %%
print("1st sample size = " + str(len(c1)))
print("2nd sample size = " + str(len(c2)))

print("1st sample mean = " + str(mean_c1))
print("2nd sample mean = " + str(mean_c2))
print("1st sample stdev = " + str(stdev_c1))
print("2nd sample stdev = " + str(stdev_c2))
print("Degrees of freedom for Student-t distribution = " + str(df))

print("\nResults:")

print("Statistics value z = " + str(z))
print("Normal distribution: p-value = " + str((1 - 0.99831) * 2)) # z tabeli
print("Student-t distribution: p-value = ")
print("Normal distribution: ")
print("Student-t distribution: ")
# Out:
# 1st sample size = 201
# 2nd sample size = 591
# 1st sample mean = 2.679
# 2nd sample mean = 2.432
# 1st sample stdev = 1.102
# 2nd sample stdev = 0.786
# Degrees of freedom for Student-t distribution = 272.43
#
# Results:
# Statistics value z = 2.993
# Normal distribution: p-value = 0.0033799999999999386
# Student-t distribution: p-value =
# Normal distribution:
# Student-t distribution:
